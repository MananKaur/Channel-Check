# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'AIzaSyChtF2IsrzyqXxL7rk7oipZapt-QMizROM'
#channel_id = 'UCGmbqvNCzyMGNw5kWnMTBKw'
channel_ids = ['UCnz-ZXXER4jOvuED5trXfEA', # techTFQ
               'UCLLw7jmFsvfIVaUFsLs8mlQ', # Luke Barousse 
               'UCiT9RITQ9PW6BhXK0y2jaeg', # Ken Jee
               'UC7cs8q-gJRlGwj4A8OmCmXg', # Alex the analyst
               'UC2UXDak6o7rBm23k3Vv5dww' # Tina Huang
              ]

youtube = build('youtube', 'v3', developerKey = api_key)

# %% [markdown]
# ## Function to get channel statistics

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                Subscribers = response['items'][i]['statistics']['subscriberCount'],
                Views = response['items'][i]['statistics']['viewCount'],
                Total_vidoes = response['items'][i]['statistics']['videoCount'],
                Playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads']    
               )
        all_data.append(data)
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#        Channel_name Subscribers     Views Total_vidoes  \
# 0        Tina Huang      561000  24889796          132
# 1           Ken Jee      250000   8484780          282
# 2           techTFQ      231000  11731807           95
# 3  Alex The Analyst      567000  23198597          239
# 4     Luke Barousse      373000  17493217          138
#
#                 Playlist_id
# 0  UU2UXDak6o7rBm23k3Vv5dww
# 1  UUiT9RITQ9PW6BhXK0y2jaeg
# 2  UUnz-ZXXER4jOvuED5trXfEA
# 3  UU7cs8q-gJRlGwj4A8OmCmXg
# 4  UULLw7jmFsvfIVaUFsLs8mlQ

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_vidoes'] = pd.to_numeric(channel_data['Total_vidoes'])
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_vidoes     int64
# Playlist_id     object
# dtype: object

# %%
sns.set(rc = {'figure.figsize':(8,6)})
ax = sns.barplot(x='Channel_name', y = 'Subscribers', data = channel_data)

# %%
sns.set(rc = {'figure.figsize':(8,6)})
ax = sns.barplot(x='Channel_name', y = 'Views', data = channel_data)

# %%
sns.set(rc = {'figure.figsize':(7,7)})
ax = sns.barplot(x='Channel_name', y = 'Total_vidoes', data = channel_data)

# %% [markdown]
# ## Function to get video ids

# %%
playlist_id = channel_data.loc[channel_data['Channel_name'] == 'Ken Jee', 'Playlist_id'].iloc[0]

# %%
##playlist_id

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
    part = 'contentDetails',
    playlistId = playlist_id,
    maxResults = 10000)
    
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
            video_ids.append(response['items'][i]['contentDetails']['videoId'])
    
    next_page_token = response.get('nextPageToken')
    more_pages = 'true'
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
            part = 'contentDetails',
            playlistId = playlist_id,
            maxResults = 50,
           pageToken = next_page_token)
    
            response = request.execute()
            
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
                
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
video_ids
# Out:
# ['w13zJB_jyBI',
#  'oZ9rMrqyTbI',
#  '6BrYKdqq4uA',
#  '1dAvbIMrLos',
#  'lqYxmYMkfK8',
#  '-JTU734oMfk',
#  'HVpbmu7rFYE',
#  'NQQ3DRdXAXE',
#  'xpi-M2j3NmE',
#  'X07w7QFoLpc',
#  'RRnThAtKuq0',
#  'r3zOpjEOkgE',
#  's-XYFEzy9Wc',
#  'iBh1wl4o6V4',
#  'L6lXKdP4Qbg',
#  'xGDl6rlBygU',
#  'SY6y6Y8C594',
#  '1RUj2aLQx8I',
#  'MkzZXSw1Glk',
#  '9neDFXTxKxA',
#  'UaNNVukM27g',
#  '3lN0-S3symM',
#  'M-AN8eWLxms',
#  'MXFZhbvQqM8',
#  '54n61XjKifI',
#  'pyWYIRR8rrE',
#  'onwRfbt--cw',
#  'u6P23ouSYhA',
#  'RMMVuvS7S_g',
#  '5AwbPAV8FS0',
#  'A2OQgU0IRNo',
#  'x5Q_nrIqFik',
#  '7ja2ELBVMlU',
#  'Z2MyLQa_vVw',
#  'JTlB9fwYRk0',
#  'OJDf_fTENJ4',
#  'nqCkdqhV-JY',
#  'b8t8lDL13sg',
#  't6CD1EwU5kc',
#  'eIxHe45hzhQ',
#  '3NJOWWvNK3I',
#  '4_VtMWJSo1o',
#  'OybXWl3IWvI',
#  'nRHPQ5ZeB5Y',
#  '0JWC4M0Qhqc',
#  'oNvyvYGw5n4',
#  'GaZRuchRCyw',
#  'EBjYqC3aNTA',
#  'QMP858aZcow',
#  '0ItYIoOrrUs',
#  'KzTFoUbThvM',
#  'bBJd0oPdNak',
#  'Yk-unX4KnV4',
#  'z0_xrtFdFj8',
#  'vVpkXEIn-q0',
#  'aipz4p7GDL4',
#  'iPdO9MwdcLE',
#  'YPph59-rTxA',
#  '-2U2CMYom00',
#  'KEeUR8UDy-s',
#  '0jTtHYie3CU',
#  '2RWwN5ZT4tA',
#  'rEWPqw6rMGI',
#  'o-wsyxWbPOw',
#  'xpIFS6jZbe8',
#  '-zbLpoJVBMI',
#  'scSc6YSanQ0',
#  'FqNpDNmpcEo',
#  'vwvdtXMcNzI',
#  '2qVWurPFwfc',
#  '35g8fCi-kbw',
#  'n6MiRgxN5iA',
#  'ammCGdzSoag',
#  '15c7WD-lKUY',
#  'TjGFBQC27ng',
#  'qUK5Vk4NvBw',
#  'cnqTU6eJwH0',
#  'k8YxyrcAXJs',
#  'VvnOXDCVm8k',
#  '68GGPK3WaqI',
#  'S4Lei5mOppc',
#  'tG_UW_p0UqE',
#  '143WWA5Sy9k',
#  's1gD35Z4eUc',
#  'nrEJGGxcoTc',
#  'KfpOuSH9gDc',
#  'sICJ6a2wX5g',
#  'iiSZqsQKNX8',
#  'IoUWD1h6xUs',
#  '7JCterBrcvk',
#  'KU__lDJj5iU',
#  '8nTmuKI2oyA',
#  'SaWxVk7rDp4',
#  'n7kjelw9s2w',
#  '8Pi36Nj6P9A',
#  'hOUrxTeBJQc',
#  '-ONQ628CXKQ',
#  'sHRq-LshG3U',
#  'EMq4PH7PCeA',
#  'BlSrorP32WM',
#  'pPfw2fzwNiM',
#  'hcHSSyHbgMQ',
#  'ITAxTid_1YU',
#  'fU3DOXjwufg',
#  'tJI-1mHeXoA',
#  'SVtRsDhHlDk',
#  'OtqQYqRNDGI',
#  'uic34RTaI-w',
#  'GO420aMtHfk',
#  'KQ80oD_boBM',
#  'r-DR9HBaipU',
#  'qV_AlRwhI3I',
#  '41Clrh6nv1s',
#  'YR9Faf1uZDg',
#  'myhoWUrSP7o',
#  'ji7DtgUeKCI',
#  '4039x4r-hGE',
#  '78LjdAAw0wA',
#  'yUrrf3Pm33s',
#  'domVw8isGOI',
#  '_0rHU6qAQe0',
#  'tnpV1etgcxs',
#  'Uf0dO-pgOrk',
#  'N97MhZEp2UQ',
#  '1Ir1NgCuI0Y',
#  'd6FeV8WXPWY',
#  'WRF_dKZ_i24',
#  'UpaEjBOMNqs',
#  'UKuK2fXu_dU',
#  'Ft4GVkQQtgk',
#  'BBDiadC8BvE',
#  '7VcdvSyoxnc',
#  '8Vxjp2KVHqs',
#  'Kq9dkZu0bpg',
#  'omdhf8d53FM',
#  'apf6A3Nstm8',
#  'jf3j0lWmFPU',
#  'g7on3Rw0Ovg',
#  'rLawTH--l2Y',
#  '-pdXWmj9xxU',
#  'vfV4nm004VQ',
#  'oHUD2T_VXfI',
#  'uXLnbdHMf8w',
#  '5v_ulmGv-gc',
#  'q6Lf2yhvluw',
#  'iGUiLWFDWfk',
#  'SsGKZe4dVyk',
#  'RAMxzqSMDKE',
#  'YbTMIxjk4hI',
#  'S_CuB__nsmI',
#  'KEBVcVwFzaI',
#  'vQGJvmhpq_s',
#  'Xgg7dIKys9E',
#  'UuR3nomI5AE',
#  '6tQtwqthUMI',
#  'QN3wXPZSjpE',
#  'rdo8YBasqqA',
#  '_rbrdNTpZGo',
#  'ELFGsNqZrlM',
#  'PWmxLYTixAM',
#  'I3FBJdiExcg',
#  'hO_YKK_0Qck',
#  '2KkrtG5IsHo',
#  'QQLToUlgN7A',
#  '6aaIbd-GpZs',
#  'lsXWVPzwZPk',
#  'AqPquogHwq0',
#  '742LQ38OioU',
#  'B1g_yMKpdwo',
#  'zGlJ-QndG8E',
#  '6fwyyRgZlD0',
#  '-3d1NctSv0c',
#  'WnB1jsDu900',
#  'XjC3FPL-S78',
#  'txR8_jGi0Ls',
#  '4qZINLzwYyk',
#  'mR2NCRgtLPE',
#  'mEZ1Hj5yQ-8',
#  'HJH0gfY6EUg',
#  'BZFfNwj7JhE',
#  '_K6cNdgN3CI',
#  '1aXk2RViq3c',
#  'UcilY6HDuL8',
#  'jam0xApfC-U',
#  '4OZip0cgOho',
#  'QBIe4nbmZfA',
#  'KHAuuOQui2U',
#  'DW55gaQ_Egk',
#  'lUUqrRgerd8',
#  'ei1m5lDQyBg',
#  '9D7GzskcyUk',
#  'agHKuUoMwvY',
#  'nUOh_lDMHOU',
#  '7O4dpR9QMIM',
#  'QWgg4w1SpJ8',
#  'fhi4dOhmW-g',
#  'GmW4F6MHqqs',
#  'MpF9HENQjDo',
#  '9ZwVqXUHf6o',
#  'a3VWq9smqhM',
#  'oMdVg6GPODA',
#  'vy-R4oUZaC8',
#  'XGBigjVy2Eo',
#  'hpMc6TgT34I',
#  'Fs_LG5Y8GIU',
#  'Ip50cXvpWY4',
#  'imMPnCHvbkY',
#  '3bes4U4MHPg',
#  'qP0hRF-lGqg',
#  'aaAZXeuPIXk',
#  'C4OPn58BLaU',
#  '8igH8qZafpo',
#  'xjhW1rSQeik',
#  'DM1eE_Coh6g',
#  'f6NPw582FFc',
#  'dlZWB2D-NaQ',
#  'foggudmDDvY',
#  'n3vw0M5RrPU',
#  '2OnXytYziF0',
#  'Q9FjwzKFPuM',
#  'VN12ZPFsApM',
#  'WKXtTo7lqmA',
#  '9-2OKLZfvbE',
#  '3TrAYmrmA8o',
#  '5SjK6YCs4o4',
#  'iqG59TqfFdY',
#  'NCyPY-jfb3I',
#  'DopikusDfk0',
#  'm5pwx3hgtzM',
#  '74Z3F7i4qcI',
#  'zSwM5uVeylU',
#  'BXmEmIK5aqI',
#  'SLC5sPZSLY4',
#  'EAezvs0eL1s',
#  'k4r_NtB4JVQ',
#  'ZWdyBbgGZBQ',
#  '1FrY7ARSf10',
#  'LGEuDWjWQes',
#  'fjVVtvp5X0w',
#  '-kX2b6TF_9k',
#  '3ysXGYjvbSU',
#  'akbU9KOo_Qc',
#  '3BEtGaz70rQ',
#  'RRXWJVX0fE8',
#  'k-gin1qfzi0',
#  'Zz_Mx1UPswI',
#  '3Mm1U1CbzNw',
#  '4yI3vVe0Jos',
#  'pWVQ0vN5uig',
#  'a-Syoa9mPhM',
#  'yukdXV9LR48',
#  'XWetgrNas-k',
#  'yIJrCFXs0rU',
#  'Z9dGmL2G-4k',
#  'T7BQJJIGrmc',
#  'T77uVbLhroQ',
#  '1Cf7SdnBncg',
#  '3cDM9Z-fdz4',
#  'Yr5T3T4tq-g',
#  'KMOA5arCi8g',
#  'Z_KFh-HqaBA',
#  '5jntoZX-Tc8',
#  'AxP1CL0yaFQ',
#  'zF_Q2v_9zKY',
#  '4CpmB4TR2C4',
#  '6sJEnzDjJqI',
#  '1UjMBw_7Gi8',
#  'q8cEt8gj3zY',
#  '_CS4u9cORwA',
#  'XTrlMQXYqts',
#  'smeFkHwnM_k',
#  'sq5TnVJWv6A',
#  'XoUyK3XHZHs',
#  'tv1e22u2COk',
#  'j-Z-je6K4Yg',
#  'sCOX5yShmFA',
#  'FBgs-BSTIJE',
#  'irjTWNV0eAY',
#  'RRSRKf9eQxc',
#  'IFceyuL6GZY',
#  'Y_SMU701qlA',
#  'qfRhKHV8-t4']

# %% [markdown]
# ## Function to get video details

# %%
def get_video_details(youtube, video_ids):
    
    all_video_stats = []
    
    for i in range(0,len(video_ids),50):
    
        request = youtube.videos().list(
            part="snippet,statistics",
            id=','.join(video_ids[i:i+50])
        )

        response = request.execute()
        
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                              Published_date = video['snippet']['publishedAt'],
                              Views = video['statistics']['viewCount'],
                            Likes = video['statistics']['likeCount'],
                                Comments = video['statistics']['commentCount']
                              )
            all_video_stats.append(video_stats)
            
    return all_video_stats

# %%
video_details = get_video_details(youtube,video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data['Published_date'] = pd.to_datetime(video_data['Published_date']).dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
video_data['Comments'] = pd.to_numeric(video_data['Comments'])
video_data
# Out:
#                                                  Title Published_date  Views  \
# 0             The Harsh Reality of the Data Job Market     2023-08-24  77435
# 1            7 Industries AI will Aggressively Disrupt     2023-08-14   4800
# 2    What's in My Data Science Travel Bag? (50+ Fli...     2023-08-07   3477
# 3                       7 Enticing Jobs AI Will Create     2023-07-24   4116
# 4            The ChatGPT Code Interpreter is OVERRATED     2023-07-22   3771
# ..                                                 ...            ...    ...
# 277                How to Simulate NBA Games in Python     2018-11-19  17638
# 278          Should You Get A Masters in Data Science?     2018-11-14  20514
# 279  How I Became A Data Scientist From a Business ...     2018-11-12   6448
# 280  Predicting Season Long NBA Wins Using Multiple...     2018-07-10   8662
# 281  Predicting Crypto-Currency Price Using RNN lST...     2017-11-18  18888
#
#      Likes  Comments
# 0     2004       223
# 1      209        37
# 2      112        47
# 3      185        36
# 4      135        31
# ..     ...       ...
# 277    390        54
# 278    305       135
# 279    196        23
# 280    193        17
# 281    292        41
#
# [282 rows x 5 columns]

# %%
top10_videos = video_data.sort_values(by = 'Views', ascending = False).head(10)
top10_videos
# Out:
#                                                  Title Published_date  \
# 184  How I Would Learn Data Science (If I Had to St...     2020-05-08
# 205  The Best Free Data Science Courses Nobody is T...     2020-03-09
# 64   How I Would Learn Data Science in 2022 (If I H...     2021-12-27
# 211  3 Proven Data Science Projects for Beginners (...     2020-02-17
# 160  Beginner Kaggle Data Science Project Walk-Thro...     2020-07-17
# 197  Data Science Project from Scratch - Part 1 (Pr...     2020-04-03
# 250  The Projects You Should Do To Get A Data Scien...     2019-07-30
# 97      Why You Probably Won't Become a Data Scientist     2021-04-09
# 112  How I Would Learn Data Science in 2021 (What H...     2020-12-19
# 181  How to Make A Data Science Portfolio Website w...     2020-05-15
#
#        Views  Likes  Comments
# 184  1392937  49023      1998
# 205   344884  21168       622
# 64    339695  14964       539
# 211   323704  17683       525
# 160   322604   7204       423
# 197   193539   4949       173
# 250   150005   5691       255
# 97    137856   4037       480
# 112   131381   5973       488
# 181   126898   4337       193

# %%
ax1 = sns.barplot(x='Views', y = 'Title', data = top10_videos)

# %%
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')

# %%
video_data
# Out:
#                                                  Title Published_date  Views  \
# 0             The Harsh Reality of the Data Job Market     2023-08-24  77435
# 1            7 Industries AI will Aggressively Disrupt     2023-08-14   4800
# 2    What's in My Data Science Travel Bag? (50+ Fli...     2023-08-07   3477
# 3                       7 Enticing Jobs AI Will Create     2023-07-24   4116
# 4            The ChatGPT Code Interpreter is OVERRATED     2023-07-22   3771
# ..                                                 ...            ...    ...
# 277                How to Simulate NBA Games in Python     2018-11-19  17638
# 278          Should You Get A Masters in Data Science?     2018-11-14  20514
# 279  How I Became A Data Scientist From a Business ...     2018-11-12   6448
# 280  Predicting Season Long NBA Wins Using Multiple...     2018-07-10   8662
# 281  Predicting Crypto-Currency Price Using RNN lST...     2017-11-18  18888
#
#      Likes  Comments Month
# 0     2004       223   Aug
# 1      209        37   Aug
# 2      112        47   Aug
# 3      185        36   Jul
# 4      135        31   Jul
# ..     ...       ...   ...
# 277    390        54   Nov
# 278    305       135   Nov
# 279    196        23   Nov
# 280    193        17   Jul
# 281    292        41   Nov
#
# [282 rows x 6 columns]

# %%
videos_per_month = video_data.groupby('Month', as_index = False).size()

# %%
videos_per_month
# Out:
#    Month  size
# 0    Apr    22
# 1    Aug    27
# 2    Dec    20
# 3    Feb    25
# 4    Jan    29
# 5    Jul    27
# 6    Jun    20
# 7    Mar    32
# 8    May    24
# 9    Nov    20
# 10   Oct    17
# 11   Sep    19

# %%
sort_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'], categories = sort_order, ordered = True)

# %%
videos_per_month = videos_per_month.sort_index()

# %%
videos_per_month
# Out:
#       Month  size
# Month
# Jan     Jan    29
# Feb     Feb    25
# Mar     Mar    32
# Apr     Apr    22
# May     May    24
# Jun     Jun    20
# Jul     Jul    27
# Aug     Aug    27
# Sep     Sep    19
# Oct     Oct    17
# Nov     Nov    20
# Dec     Dec    20

# %%
ax2 = sns.barplot(x = 'Month', y = 'size', data = videos_per_month)
